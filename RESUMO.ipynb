# %%
import pandas as pd

# %%
df_population_data = pd.read_csv('C:/Users/thelsandro/Documents/GitHub/resumo_pandas_python/lojas.csv')

# %%
df_population_data
# Out:
#       Store StoreType Assortment  CompetitionDistance  \
# 0         1         c          a               1270.0
# 1         2         a          a                570.0
# 2         3         a          a              14130.0
# 3         4         c          c                620.0
# 4         5         a          a              29910.0
# ...     ...       ...        ...                  ...
# 1110   1111         a          a               1900.0
# 1111   1112         c          c               1880.0
# 1112   1113         a          c               9260.0
# 1113   1114         a          c                870.0
# 1114   1115         d          c               5350.0
#
#       CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                           9.0                    2008.0       0
# 1                          11.0                    2007.0       1
# 2                          12.0                    2006.0       1
# ...

# %%
type(df_population_data)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.set_option('display.max_rows',1115)

# %%
pd.set_option('display.max_columns',5)

# %%
df_population_data
# Out:
#       Store StoreType  ... Promo2SinceYear     PromoInterval
# 0         1         c  ...             NaN               NaN
# 1         2         a  ...          2010.0   Jan,Apr,Jul,Oct
# 2         3         a  ...          2011.0   Jan,Apr,Jul,Oct
# 3         4         c  ...             NaN               NaN
# 4         5         a  ...             NaN               NaN
# 5         6         a  ...             NaN               NaN
# 6         7         a  ...             NaN               NaN
# 7         8         a  ...             NaN               NaN
# 8         9         a  ...             NaN               NaN
# 9        10         a  ...             NaN               NaN
# 10       11         a  ...          2012.0   Jan,Apr,Jul,Oct
# 11       12         a  ...          2010.0   Jan,Apr,Jul,Oct
# 12       13         d  ...          2009.0   Feb,May,Aug,Nov
# 13       14         a  ...          2011.0   Jan,Apr,Jul,Oct
# ...

# %%
pd.reset_option('display.max_columns')

# %%
df_population_data
# Out:
#       Store StoreType Assortment  CompetitionDistance  \
# 0         1         c          a               1270.0
# 1         2         a          a                570.0
# 2         3         a          a              14130.0
# 3         4         c          c                620.0
# 4         5         a          a              29910.0
# 5         6         a          a                310.0
# 6         7         a          c              24000.0
# 7         8         a          a               7520.0
# 8         9         a          c               2030.0
# 9        10         a          a               3160.0
# 10       11         a          c                960.0
# 11       12         a          c               1070.0
# 12       13         d          a                310.0
# 13       14         a          a               1300.0
# 14       15         d          c               4110.0
# 15       16         a          c               3270.0
# ...

# %%
df_population_data.head() #5 primeiras linhas
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# ...

# %%
df_population_data.head(10) # as 10 primeiras linhas
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
# 5      6         a          a                310.0                       12.0
# 6      7         a          c              24000.0                        4.0
# 7      8         a          a               7520.0                       10.0
# 8      9         a          c               2030.0                        8.0
# 9     10         a          a               3160.0                        9.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# ...

# %%
df_population_data.tail(10) #as 10 últimas linhas
# Out:
#       Store StoreType Assortment  CompetitionDistance  \
# 1105   1106         a          c               5330.0
# 1106   1107         a          a               1400.0
# 1107   1108         a          a                540.0
# 1108   1109         c          a               3490.0
# 1109   1110         c          c                900.0
# 1110   1111         a          a               1900.0
# 1111   1112         c          c               1880.0
# 1112   1113         a          c               9260.0
# 1113   1114         a          c                870.0
# 1114   1115         d          c               5350.0
#
#       CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 1105                        9.0                    2011.0       1
# 1106                        6.0                    2012.0       1
# 1107                        4.0                    2004.0       0
# 1108                        4.0                    2011.0       1
# ...

# %%
df_population_data.sample(10) # 10 itens aleatórios
# Out:
#      Store StoreType Assortment  CompetitionDistance  \
# 857    858         a          a               3370.0
# 79      80         d          a               7910.0
# 843    844         a          a               2030.0
# 40      41         d          c               1180.0
# 800    801         d          a              48330.0
# 574    575         a          a                960.0
# 869    870         a          a                780.0
# 530    531         a          c               4030.0
# 577    578         d          a              12700.0
# 822    823         a          c              16210.0
#
#      CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 857                       12.0                    2008.0       1
# 79                         NaN                       NaN       0
# 843                        9.0                    2012.0       1
# 40                         NaN                       NaN       1
# ...

# %%
df_population_data.info() #informações
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Store                      1115 non-null   int64
#  1   StoreType                  1115 non-null   object
#  2   Assortment                 1115 non-null   object
#  3   CompetitionDistance        1112 non-null   float64
#  4   CompetitionOpenSinceMonth  761 non-null    float64
#  5   CompetitionOpenSinceYear   761 non-null    float64
#  6   Promo2                     1115 non-null   int64
#  7   Promo2SinceWeek            571 non-null    float64
#  8   Promo2SinceYear            571 non-null    float64
#  9   PromoInterval              571 non-null    object
# dtypes: float64(5), int64(2), object(3)
# memory usage: 87.2+ KB

# %%
df_population_data.describe()
# Out:
#             Store  CompetitionDistance  CompetitionOpenSinceMonth  \
# count  1115.00000          1112.000000                 761.000000
# mean    558.00000          5404.901079                   7.224704
# std     322.01708          7663.174720                   3.212348
# min       1.00000            20.000000                   1.000000
# 25%     279.50000           717.500000                   4.000000
# 50%     558.00000          2325.000000                   8.000000
# 75%     836.50000          6882.500000                  10.000000
# max    1115.00000         75860.000000                  12.000000
#
#        CompetitionOpenSinceYear       Promo2  Promo2SinceWeek  Promo2SinceYear
# count                761.000000  1115.000000       571.000000       571.000000
# mean                2008.668857     0.512108        23.595447      2011.763573
# std                    6.195983     0.500078        14.141984         1.674935
# ...

# %%
df_population_data.describe().round(0)
# Out:
#         Store  CompetitionDistance  CompetitionOpenSinceMonth  \
# count  1115.0               1112.0                      761.0
# mean    558.0               5405.0                        7.0
# std     322.0               7663.0                        3.0
# min       1.0                 20.0                        1.0
# 25%     280.0                718.0                        4.0
# 50%     558.0               2325.0                        8.0
# 75%     836.0               6882.0                       10.0
# max    1115.0              75860.0                       12.0
#
#        CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear
# count                     761.0  1115.0            571.0            571.0
# mean                     2009.0     1.0             24.0           2012.0
# std                         6.0     1.0             14.0              2.0
# min                      1900.0     0.0              1.0           2009.0
# ...
